# %% [markdown]
# ## 📚 Modules Index
#
# ### PHASE 1: AI FOUNDATIONS & LLM FUNDAMENTALS (DAYS 1–14)
# - [Day 01: Refactor a legacy Python script to use advanced functions and strict type hinting (Pydantic).](day_01.ipynb)
# - [Day 02: Implement file manipulation scripts that handle large-scale JSONL data processing for AI datasets.](day_02.ipynb)
# - [Day 03: Build a class-based Python wrapper for an LLM API that handles retries, manages state cleanly, and structures object interactions.](day_03.ipynb)
# - [Day 04: Write a Python decorator to measure token usage and latency for every LLM call.](day_04.ipynb)
# - [Day 05: Build a FastAPI endpoint that integrates an LLM and uses decorators for authentication.](day_05.ipynb)
# - [Day 06: Develop a Streamlit UI that takes user input and interacts with the Groq API for sub-second responses.](day_06.ipynb)
# - [Day 07: Deploy your first LLM-powered app on Streamlit Cloud and integrate basic logging.](day_07.ipynb)
# - [Day 08: Implement a Scaled Dot-Product Attention mechanism from scratch using NumPy.](day_08.ipynb)
# - [Day 09: Map the Transformer architecture by coding the Positional Encoding and Multi-Head Attention blocks.](day_09.ipynb)
# - [Day 10: Visualize attention weights using a pre-trained GPT-2 model to see how context is processed.](day_10.ipynb)
# - [Day 11: Generate and store text embeddings using sentence-transformers and compute cosine similarity.](day_11.ipynb)
# - [Day 12: Implement a semantic search script that finds the most relevant document from a local text batch.](day_12.ipynb)
# - [Day 13: Benchmark LLM parameter variance: Run 10 iterations of the same prompt while varying Temperature, Top-P, and Frequency Penalty.](day_13.ipynb)
# - [Day 14: Implement a "System Prompt" versioning system to track how different instructions change model outputs.](day_14.ipynb)
#
# ### PHASE 2: VECTOR DATABASES & RAG FOUNDATIONS (DAYS 15–28)
# - [Day 15: Spin up a local Qdrant instance via Docker and initialize a collection with custom vector dimensions.](day_15.ipynb)
# - [Day 16: Perform CRUD operations in Qdrant: Insert, update, and delete vectors with specific metadata payloads.](day_16.ipynb)
# - [Day 17: Implement a "Pure Python RAG" pipeline: Manually fetch context from a JSON file based on similarity and inject it into a prompt.](day_17.ipynb)
# - [Day 18: Implement Advanced Qdrant Operations: Use filtered searches and scroll APIs to manage large datasets.](day_18.ipynb)
# - [Day 19: Build a script to handle RAG "Context Overflow" by implementing a basic sliding window for retrieved text.](day_19.ipynb)
# - [Day 20: Refactor your Pure Python RAG to use Qdrant as the permanent storage layer.](day_20.ipynb)
# - [Day 21: Implement a performance benchmark: Measure search latency in Qdrant across 1,000 vs 10,000 vectors.](day_21.ipynb)
# - [Day 22: Initialize a LangChain RAG chain and replace your manual retrieval logic.](day_22.ipynb)
# - [Day 23: Implement LangChain "Chains" vs "Expressions" (LCEL) to create a modular retrieval pipeline.](day_23.ipynb)
# - [Day 24: Integrate Docling to parse complex PDFs with tables into structured markdown for the LLM.](day_24.ipynb)
# - [Day 25: Implement Recursive Character Text Splitting and compare it with token-based chunking.](day_25.ipynb)
# - [Day 26: Build a "Hierarchical Chunking" strategy: Create parent chunks for context and child chunks for retrieval.](day_26.ipynb)
# - [Day 27: Refactor the LangChain pipeline to support multiple document types (PDF, MD, TXT).](day_27.ipynb)
# - [Day 28: Finalize the "Smart Chunking" project: A pipeline that maintains table structure during retrieval.](day_28.ipynb)
#
# ### PHASE 3: ADVANCED RAG & AGENTIC AI (DAYS 29–42)
# - [Day 29: Implement Hybrid Search in Qdrant: Combine Dense Vectors with Sparse Vectors (BM25) for keyword accuracy.](day_29.ipynb)
# - [Day 30: Build a "Self-Querying Retriever" that uses an LLM to turn natural language into Qdrant metadata filters.](day_30.ipynb)
# - [Day 31: Implement SQL RAG: Use LangChain to translate natural language queries into executable SQL against a SQLite DB.](day_31.ipynb)
# - [Day 32: Build a Graph RAG prototype: Extract entities and relationships from text to build a Knowledge Graph.](day_32.ipynb)
# - [Day 33: Implement a Cross-Encoder Reranker to re-order the top 10 retrieved documents for maximum relevance.](day_33.ipynb)
# - [Day 34: Optimize the RAG pipeline using  **DSPy**  to programmatically improve your retrieval prompts.](day_34.ipynb)
# - [Day 35: Audit RAG performance: Identify "Lost in the Middle" phenomena in long-context retrieval.](day_35.ipynb)
# - [Day 36: Implement the ReAct (Reasoning and Acting) loop manually in Python to understand agent logic.](day_36.ipynb)
# - [Day 37: Define a Pydantic-based schema for "Tool Calling" and integrate a simple search tool.](day_37.ipynb)
# - [Day 38: Build your first autonomous Agent using LangChain that can use a calculator and search the web.](day_38.ipynb)
# - [Day 39: Implement a  **Semantic Router**  to classify user intent and route queries to different agents.](day_39.ipynb)
# - [Day 40: Integrate conversational memory: Use WindowBufferMemory and SummaryMemory to maintain context.](day_40.ipynb)
# - [Day 41: Build a professional UI for your agent using  **Chainlit** , enabling real-time token streaming.](day_41.ipynb)
# - [Day 42: Implement "Human-in-the-loop" (HITL) patterns in Chainlit to approve sensitive agent actions.](day_42.ipynb)
#
# ### PHASE 4: AGENT ORCHESTRATION & MULTI-AGENT SYSTEMS (DAYS 43–56)
# - [Day 43: Map a complex workflow into a LangGraph state machine with Nodes (functions) and Edges (logic).](day_43.ipynb)
# - [Day 44: Implement "Statelessness" in LangGraph: Ensure each node execution only depends on the current state object.](day_44.ipynb)
# - [Day 45: Rebuild the ReAct loop inside LangGraph using conditional edges for tool execution.](day_45.ipynb)
# - [Day 46: Implement "Persistence" in LangGraph to allow agents to resume conversations across sessions.](day_46.ipynb)
# - [Day 47: Build a "Correction Loop" where an agent critiques and fixes its own output based on tool results.](day_47.ipynb)
# - [Day 48: Implement "Timeouts" and "Retry Logic" within your graph to handle API rate limits.](day_48.ipynb)
# - [Day 49: Create a visualization of your graph architecture using LangGraph's built-in drawing tools.](day_49.ipynb)
# - [Day 50: Design a Multi-Agent "Supervisor" architecture where one agent delegates tasks to specialists.](day_50.ipynb)
# - [Day 51: Implement Agent "Hand-offs": Code the logic for a "Triage Agent" to pass a state to a "Technical Agent."](day_51.ipynb)
# - [Day 52: Build a Multi-Agent workflow for "GitHub Automation": One agent reads issues, another writes code.](day_52.ipynb)
# - [Day 53: Integrate a "Reviewer Agent" into the GitHub flow to check code quality before "finalizing."](day_53.ipynb)
# - [Day 54: Implement parallel execution: Have multiple agents work on sub-tasks simultaneously in LangGraph.](day_54.ipynb)
# - [Day 55: Build a "Conflict Resolver" for agents that provides conflicting tool outputs.](day_55.ipynb)
# - [Day 56: Finalize the GitHub Agent: Automate the process from "Issue Description" to "Draft PR."](day_56.ipynb)
#
# ### PHASE 5: EVALUATION, OBSERVABILITY & MULTIMODAL AI (DAYS 57–70)
# - [Day 57: Setup  **Ragas**  and compute Faithfulness and Answer Relevancy for your RAG pipeline.](day_57.ipynb)
# - [Day 58: Implement "LLM-as-a-Judge": Create an evaluation prompt that scores agent performance.](day_58.ipynb)
# - [Day 59: Integrate  **Weights & Biases (W\&B)**  to track LLM traces and visualize prompt iterations.](day_59.ipynb)
# - [Day 60: Run an "Adversarial Attack" test on your agent to check for prompt injection and jailbreaking vulnerabilities.](day_60.ipynb)
# - [Day 61: Build an Eval Harness: Create a golden dataset of 50 Q\&A pairs for your capstone topic.](day_61.ipynb)
# - [Day 62: Interpret Eval metrics: Use W\&B to identify which chunking strategy led to the highest RAG score.](day_62.ipynb)
# - [Day 63: Implement  **Guardrails & PII Protection:** Use a secondary LLM call to verify safety, protect PII data, and build fallback mechanisms for model failures.](day_63.ipynb)
# - [Day 64: Extract structured JSON data from a complex image (invoice/chart) using a Vision model (GPT-4o/Claude).](day_64.ipynb)
# - [Day 65: Build a Multimodal RAG system: Embed both text descriptions and image features for retrieval.](day_65.ipynb)
# - [Day 66: Implement a pipeline to process multi-page PDFs where context is split between text and diagrams.](day_66.ipynb)
# - [Day 67: Build a "Visual Reasoning" agent that can answer questions about a uploaded video frame.](day_67.ipynb)
# - [Day 68: Optimize Multimodal performance: Implement image resizing and preprocessing to reduce latency.](day_68.ipynb)
# - [Day 69: Integrate the Multimodal RAG into a Chainlit UI for file uploads.](day_69.ipynb)
# - [Day 70: Benchmark Multimodal retrieval: Does adding image context actually improve the Ragas score?](day_70.ipynb)
#
# ### PHASE 6: CLOUD DEPLOYMENT, MCP & CONTEXT ENGINEERING (DAYS 71–84)
# - [Day 71: Containerize your LangChain/LangGraph application using Docker.](day_71.ipynb)
# - [Day 72: Deploy your agent container to  **AWS AgentCore**  and configure environment secrets.](day_72.ipynb)
# - [Day 73: Implement AWS-specific logging and monitoring for your deployed agent.](day_73.ipynb)
# - [Day 74: Build your first  **Model Context Protocol (MCP)**  Server to expose local files to an AI client.](day_74.ipynb)
# - [Day 75: Implement an MCP Client that can dynamically query your MCP Server for context.](day_75.ipynb)
# - [Day 76: Standardize data exchange: Use MCP to bridge the gap between your local database and the LLM.](day_76.ipynb)
# - [Day 77: Build a "Compound AI System": Integrate a LangGraph multi-agent flow with an MCP server.](day_77.ipynb)
# - [Day 78: Master Context Engineering: Implement a "Context Pruning" script to keep prompts under token limits.](day_78.ipynb)
# - [Day 79: Integrate  **deepagents**  for specialized context handling in complex multi-agent hand-offs.](day_79.ipynb)
# - [Day 80: Setup  **LangSmith**  to debug context propagation and find exactly where an agent lost its "memory."](day_80.ipynb)
# - [Day 81: Prepare a synthetic dataset for fine-tuning using an LLM to generate high-quality instruction-response pairs.](day_81.ipynb)
# - [Day 82: Use  **Unsloth**  to perform a LoRA/QLoRA fine-tuning run on a Small Language Model (SLM).](day_82.ipynb)
# - [Day 83: Export your fine-tuned model weights and convert them to GGUF format.](day_83.ipynb)
# - [Day 84: Setup  **Ollama**  and run your fine-tuned SLM locally, testing it against your RAG pipeline.](day_84.ipynb)
#
# ### PHASE 7: SYSTEM DESIGN, VOICE AI & CAREER PREP (DAYS 85–90)
# - [Day 85: Build a Voice AI stack: Integrate Speech-to-Text (Whisper) and Text-to-Speech (ElevenLabs).](day_85.ipynb)
# - [Day 86: Implement "Interruption Handling" and "Silence Detection" for a low-latency (\<800ms) voice agent.](day_86.ipynb)
# - [Day 87: Inference Engineering: Serve  **Qwen 2.5-3B**  as a REST API using  **vLLM**  with quantization (AWQ/FP8).](day_87.ipynb)
# - [Day 88: ](day_88.ipynb)
# - [Day 89: **AI System Design:**  Refactor your project with Rate Limiting, Circuit Breakers, and Model Routing logic.](day_89.ipynb)
# - [Day 90: **Career Branding & Take-Home Prep:**  Finalize your GitHub READMEs, update LinkedIn, and record a 5-minute async video explanation detailing your Capstone design decisions and problem-solving process.](day_90.ipynb)
